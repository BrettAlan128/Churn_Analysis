# %%
import pandas as pd

# %%
areacode= pd.read_csv('areacode.csv')
extended= pd.read_csv('full_df.csv')
to_tableau= pd.read_csv('regression_df.csv')
to_tableau.head()
# Out:
#    Unnamed: 0   Region  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0           0  Pacific           24.00           219.0                  22.0
# 1           1  Pacific           53.69           144.0                  50.0
# 2           2  Pacific           74.37           585.0                  81.0
# 3           3  Pacific           95.00          1592.0                  75.0
# 4           4  Pacific           84.36          1269.0                  75.0
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                   0.25             0.0           0.0             -157.0
# 1                   0.00             0.0           0.0               72.0
# 2                   0.99             0.0           0.0               77.0
# 3                  10.89             7.0           0.0              210.0
# 4                   1.98             0.0           5.8             -104.0
#
# ...

# %%
areacode.head(2)
# Out:
#    Unnamed: 0  CustomerID  AreaCode   State   Region  MonthlyRevenue  \
# 0           0     3000002       503  Oregon  Pacific           24.00
# 1           1     3000982       503  Oregon  Pacific           53.69
#
#    MonthlyMinutes  TotalRecurringCharge  DirectorAssistedCalls  \
# 0           219.0                  22.0                   0.25
# 1           144.0                  50.0                   0.00
#
#    OverageMinutes  ...  IncomeGroup  OwnsMotorcycle  \
# 0             0.0  ...            4              No
# 1             0.0  ...            5              No
#
#    AdjustmentsToCreditRating  HandsetPrice  MadeCallToRetentionTeam  \
# 0                          0            30                      Yes
# 1                          0           130                       No
#
#    CreditRating  PrizmCode    Occupation  MaritalStatus  Churn
# 0     1-Highest   Suburban  Professional             No    Yes
# 1     1-Highest   Suburban         Other        Unknown     No
#
# ...

# %%
extended.head(2)
# Out:
#    Unnamed: 0  CustomerID   State   Region  MonthlyRevenue  MonthlyMinutes  \
# 0           0     3000002  Oregon  Pacific           24.00           219.0
# 1           1     3000982  Oregon  Pacific           53.69           144.0
#
#    TotalRecurringCharge  DirectorAssistedCalls  OverageMinutes  RoamingCalls  \
# 0                  22.0                   0.25             0.0           0.0
# 1                  50.0                   0.00             0.0           0.0
#
#    ...  AgeGroupHH1  Dropped_cat  Monthly_Charge_cat  CareCalls_cat  \
# 0  ...       middle          low                 low            low
# 1  ...        young          low                high            low
#
#    OffpeakCalls_cat  TotalCalls_cat  Referrals_bin  RetentionCalls_cat  Churn  \
# 0          moderate             low           None                None    Yes
# 1          moderate        moderate           None                None     No
#
#    Churn1
# 0       1
# 1       0
#
# [2 rows x 68 columns]

# %%
to_tableau.head(2)
to_tableau['AreaCode']= areacode['AreaCode']
to_tableau['Churn_yn']= extended['Churn']
to_tableau['State']= areacode['State']
to_tableau['CustomerID']= extended['CustomerID']
Reorder= ['CustomerID','AreaCode', 'State','Region', 'MonthlyRevenue', 'MonthlyMinutes',
       'TotalRecurringCharge', 'DirectorAssistedCalls', 'OverageMinutes',
       'RoamingCalls', 'PercChangeMinutes', 'PercChangeRevenues',
       'DroppedCalls', 'BlockedCalls', 'UnansweredCalls', 'CustomerCareCalls',
       'ThreewayCalls', 'ReceivedCalls', 'OutboundCalls', 'InboundCalls',
       'PeakCallsInOut', 'OffPeakCallsInOut', 'DroppedBlockedCalls',
       'CallForwardingCalls', 'CallWaitingCalls', 'MonthsInService',
       'UniqueSubs', 'ActiveSubs', 'Handsets', 'HandsetModels',
       'CurrentEquipmentDays', 'AgeHH1', 'ChildrenInHH', 'HandsetRefurbished',
       'HandsetWebCapable', 'TruckOwner', 'RVOwner', 'Homeownership',
       'BuysViaMailOrder', 'RespondsToMailOffers', 'OptOutMailings',
       'NonUSTravel', 'OwnsComputer', 'HasCreditCard', 'RetentionCalls',
       'RetentionOffersAccepted', 'NewCellphoneUser', 'NotNewCellphoneUser',
       'ReferralsMadeBySubscriber', 'IncomeGroup', 'OwnsMotorcycle',
       'AdjustmentsToCreditRating', 'HandsetPrice', 'MadeCallToRetentionTeam',
       'PrizmCode', 'Occupation', 'MaritalStatus', 'CreditRating_split',
       'AgeGroupHH1', 'Churn1', 'Churn_yn', ]

to_tableau= to_tableau[Reorder]
to_tableau.to_csv('tableau.csv')
